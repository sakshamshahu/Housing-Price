# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

script_dir = '/Users/saksham/Projects/Housing-Price/' #<-- path of root working directory
file = 'data/interim/housing_data.csv' #<-- path of the file to be imported.

# %%
df=pd.read_csv(os.path.normcase(os.path.join(script_dir, file)))
df
# Out:
#            status   bed      bath  acre_lot          city        state  \
# 0        for_sale   3.0  2.000000      0.12      Adjuntas  Puerto Rico
# 1        for_sale   4.0  2.000000      0.08      Adjuntas  Puerto Rico
# 2        for_sale   2.0  1.000000      0.15    Juana Diaz  Puerto Rico
# 3        for_sale   4.0  2.000000      0.10         Ponce  Puerto Rico
# 4        for_sale   6.0  2.000000      0.05      Mayaguez  Puerto Rico
# ...           ...   ...       ...       ...           ...          ...
# 1400287  for_sale   3.0  2.487507    155.00    Perrysburg     New York
# 1400288  for_sale   4.0  2.000000      0.36  Silver Creek     New York
# 1400289  for_sale  10.0  4.000000      0.43       Brocton     New York
# 1400290  for_sale   2.0  2.000000      0.14       Dunkirk     New York
# 1400291  for_sale   5.0  2.000000      0.14        Angola     New York
#
#          zip_code   house_size prev_sold_date     price
# 0           601.0   920.000000            NaN  105000.0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['house_size'], bins=30, kde=True)
plt.title('Distribution of House Size')
plt.xlabel('House Size')
plt.ylabel('Frequency')
plt.ticklabel_format(style='plain', axis='both')  # Remove powers
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='house_size', y='price', data=df)
plt.title('House Size vs. Price')
plt.xlabel('House Size')
plt.ylabel('Price')
plt.ticklabel_format(style='plain', axis='both')  # Remove powers
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='state', y='price', data=df)
plt.title('Price Distribution by State')
plt.xlabel('State')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.ticklabel_format(style='plain', axis='y')  # Remove powers
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='acre_lot', y='price', data=df)
plt.title('Lot Size vs. Price')
plt.xlabel('Lot Size (acres)')
plt.ylabel('Price')
plt.ticklabel_format(style='plain', axis='both')  # Remove powers
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='status', data=df)
plt.title('Count of Houses by Status')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, annot_kws={"size": 10})
plt.title('Correlation Matrix Heatmap with Values')
plt.show()

# %%
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='state', y='price', data=df, ci=None)
plt.title('Average Price by State')
plt.xlabel('State')
plt.ylabel('Average Price')
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /var/folders/7r/6ddg9fln51g0btfrqr4y8r_m0000gn/T/ipykernel_51884/996654391.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='state', y='price', data=df, ci=None)
